# %% [markdown]
# # **Курс "Програмування на мові Python"**
#
# ##### Викладачі:
# ##### Борисенко Павло Борисович
# ##### Щьоголєв Максим Олегович

# %% [markdown]
# ## **Практичне зайняття №8**
#
# ### Тема: "Робота з функціями. Локальні та глобальні змінні"

# %% [markdown]
# ### **Завдання 1 (3 бали)**
#
# **Підрахувати визначник матриці, використовуючи перестановки та символ Леві-Чивіти.**
#
# Функція random_matrix() призначена для створення квадратної матриці випадкових чисел. Її змінювати непотрібно.
#
# Приклад використання методу permutations() для створення списку перестановок також подається у комірці з кодом.
#
# 1) Створити 3 функції: функцію створення списку перестановок, функцію підрахунку добутків та функцію підрахунку загальної суми.
#
# 2) Кожна функція має супроводжуватись рядком документації, що буде коротко описувати її призначення.
#
# 3) Розмірність квадратної матриці має вводитись користувачем з клавіатури. Підрахунки виконувати лише в тому разі, якщо користувач введе ціле додатне число.
#
# 4) Загальний результат повинен підраховуватись за допомогою композиції функцій.
#
# За бажання можна перевірити правильність роботи програми за допомогою функції np.linalg.det(a).

# %%
import numpy as np
import itertools


def input_positive_int(input_message):
    """
    This function organizes the input of a positive integer
    with output of error messages and support information.
    """
    while True:
        input_value = input(input_message)
        try:
            variable_value = int(input_value)
        except ValueError:
            print(f'"{input_value}" - не є цілим додатнім числом'    
                  '\nСпробуйте знову')
        else:
            if variable_value <= 0:
                print(f'"{input_value}" - не є цілим додатнім числом'
                      '\nСпробуйте знову')
            else:
                return variable_value    # Вивдення значення з функції


def print_matrix(matrix, change_line=True):
    """
    This function organizes the output of the matrix to the console.
    """
    for i in range(0, len(matrix)):
        for j in range(0, len(matrix[i])):
            print(f'a[{i},{j}] = {matrix[i][j]}', end='   ')
        if i != len(matrix) - 1 or change_line:
            print()


def input_matrix(dim):
    """
    This function organizes the input of the matrix by the user from the keyboard.
    """
    def print_incomplete_matrix():
        """
        This function organizes the output of an underfilled matrix to the console
        for use as a support information to the input.
        """
        nonlocal matrix, dim
        print('\nВведення матриці:'
              '\n*якщо буде введено не число, відповідний елемент буде прирівняно до 0')
        if len(matrix) > 0:
            if len(matrix[0]) > 0:
                print_matrix(matrix, False)
                lines_num = len(matrix)
                last_line_len = len(matrix[lines_num - 1])
                if last_line_len != dim:
                    for s in range(last_line_len, dim):
                        print(f'a[{lines_num - 1},{s}] = ___', end='   ')
                    print()
                if lines_num != dim:
                    for l in range(lines_num, dim):
                        for s in range(0, dim):
                            print(f'a[{l},{s}] = ___', end=' ')
                        print()

    def force_to_float(input_value):
        """
        This function checks if the input_value passed to it can be cast to float.
        If yes, it returns that number, else, it returns 0.
        """
        output_value = 0
        try:
            output_value = float(input_value)
        finally:
            return output_value

    matrix = []
    for i in range(0, dim):
        matrix.append([])
        for j in range(0, dim):
            print_incomplete_matrix()
            matrix[i].append(force_to_float(input(f'\na[{i},{j}] =? ')))
    return matrix


def random_matrix(dim):
    """
    The function generates dim x dim array of integers
    between 0 and 10.
    """
    matrix = np.random.randint(10, size = (dim, dim))
    return matrix


def find_permutations(length):
    """
    This function returns all permutations of numbers from 1 to n.
    """
    return list(itertools.permutations([i for i in range(0, length)], length))


def find_multiply(permutations, matrix, dim):
    """
    This function calculates all multiplications considering
    the number of inversions.
    """
    multiplys = []
    for permutation in permutations:
        multiply_res = 1
        for i in range(0, dim):
            multiply_res *= matrix[i][permutation[i]]
        inv_num = 0
        for i in range(0, dim - 1):
            for j in range(i+1, dim):
                if permutation[i] > permutation[j]:
                    inv_num += 1
        multiply_res *= np.power(-1, inv_num)
        multiplys.append(multiply_res)
    return multiplys


def find_sum(multiplys):
    """
    This function sums all the results of multiplication
    and returns the final result.
    """
    sum_res = 0
    for x in multiplys:
        sum_res += x
    return sum_res


n = input_positive_int('Уведіть розмірність матриці: ')
print('Виберіть режим заповнення матриці:'
      '\n    "r" - автоматичне заповнення випадковими числами в діапазоні від 1 до 10'
      '\n    "m" - ручне заповнення матриці'
      '\n*уведіть відповідну літеру (введення будь-якої іншої літери означатиме режим "r")')
if input('?').lower() == 'm':
    work_matrix = input_matrix(n)
else:
    work_matrix = random_matrix(n)
print('\nЗаповнена матриця:')
print_matrix(work_matrix)
if n == 1:
    determinator = work_matrix[0][0]
else:
    determinator = find_sum(find_multiply(find_permutations(n), work_matrix, n))
print('Визначник цієї матриці =', determinator)
print('*результат, розрахований програмою')
print('\nРезультат, розрахований функцією з умови:', np.linalg.det(work_matrix))
import numpy as np
import itertools


def input_positive_int(input_message):
    """
    This function organizes the input of a positive integer
    with output of error messages and support information.
    """
    while True:
        input_value = input(input_message)
        try:
            variable_value = int(input_value)
        except ValueError:
            print(f'"{input_value}" - не є цілим додатнім числом'    
                  '\nСпробуйте знову')
        else:
            if variable_value <= 0:
                print(f'"{input_value}" - не є цілим додатнім числом'
                      '\nСпробуйте знову')
            else:
                return variable_value    # Вивдення значення з функції


def print_matrix(matrix, change_line=True):
    """
    This function organizes the output of the matrix to the console.
    """
    for i in range(0, len(matrix)):
        for j in range(0, len(matrix[i])):
            print(f'a[{i},{j}] = {matrix[i][j]}', end='   ')
        if i != len(matrix) - 1 or change_line:
            print()


def input_matrix(dim):
    """
    This function organizes the input of the matrix by the user from the keyboard.
    """
    def print_incomplete_matrix():
        """
        This function organizes the output of an underfilled matrix to the console
        for use as a support information to the input.
        """
        nonlocal matrix, dim
        print('\nВведення матриці:'
              '\n*якщо буде введено не число, відповідний елемент буде прирівняно до 0')
        if len(matrix) > 0:
            if len(matrix[0]) > 0:
                print_matrix(matrix, False)
                lines_num = len(matrix)
                last_line_len = len(matrix[lines_num - 1])
                if last_line_len != dim:
                    for s in range(last_line_len, dim):
                        print(f'a[{lines_num - 1},{s}] = ___', end='   ')
                    print()
                if lines_num != dim:
                    for l in range(lines_num, dim):
                        for s in range(0, dim):
                            print(f'a[{l},{s}] = ___', end=' ')
                        print()

    def force_to_float(input_value):
        """
        This function checks if the input_value passed to it can be cast to float.
        If yes, it returns that number, else, it returns 0.
        """
        output_value = 0
        try:
            output_value = float(input_value)
        finally:
            return output_value

    matrix = []
    for i in range(0, dim):
        matrix.append([])
        for j in range(0, dim):
            print_incomplete_matrix()
            matrix[i].append(force_to_float(input(f'\na[{i},{j}] =? ')))
    return matrix


def random_matrix(dim):
    """
    The function generates dim x dim array of integers
    between 0 and 10.
    """
    matrix = np.random.randint(10, size = (dim, dim))
    return matrix


def find_permutations(length):
    """
    This function returns all permutations of numbers from 1 to n.
    """
    return list(itertools.permutations([i for i in range(0, length)], length))


def find_multiply(permutations, matrix, dim):
    """
    This function calculates all multiplications considering
    the number of inversions.
    """
    multiplys = []
    for permutation in permutations:
        multiply_res = 1
        for i in range(0, dim):
            multiply_res *= matrix[i][permutation[i]]
        inv_num = 0
        for i in range(0, dim - 1):
            for j in range(i+1, dim):
                if permutation[i] > permutation[j]:
                    inv_num += 1
        multiply_res *= np.power(-1, inv_num)
        multiplys.append(multiply_res)
    return multiplys


def find_sum(multiplys):
    """
    This function sums all the results of multiplication
    and returns the final result.
    """
    sum_res = 0
    for x in multiplys:
        sum_res += x
    return sum_res


n = input_positive_int('Уведіть розмірність матриці: ')
print('Виберіть режим заповнення матриці:'
      '\n    "r" - автоматичне заповнення випадковими числами в діапазоні від 1 до 10'
      '\n    "m" - ручне заповнення матриці'
      '\n*уведіть відповідну літеру (введення будь-якої іншої літери означатиме режим "r")')
if input('?').lower() == 'm':
    work_matrix = input_matrix(n)
else:
    work_matrix = random_matrix(n)
print('\nЗаповнена матриця:')
print_matrix(work_matrix)
if n == 1:
    determinator = work_matrix[0][0]
else:
    determinator = find_sum(find_multiply(find_permutations(n), work_matrix, n))
print('Визначник цієї матриці =', determinator)
print('*результат, розрахований програмою')
print('\nРезультат, розрахований функцією з умови:', np.linalg.det(work_matrix))
